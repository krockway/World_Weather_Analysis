# %%
import pandas as pd
import gmaps
import requests
import matplotlib.pyplot as plt
import numpy as np

# Import the API key.
from config import g_key
from config import weather_api_key
from citipy import citipy
from datetime import datetime

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
#zip them together
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 736

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
#enumerate will get the index of the city for logging purposes & the city for creating the URL

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
        #(" ","+") means that it will remove spaces from city name & replace with +

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except KeyError:
        print("City not found. Skipping...")
        pass
            #Pass should be avoided
            #This means stop here and start back at the top, don't print the next line


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | yeniseysk
# Processing Record 3 of Set 1 | mergui
# City not found. Skipping...
# Processing Record 4 of Set 1 | arlit
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | yumen
# Processing Record 7 of Set 1 | sao jose da coroa grande
# Processing Record 8 of Set 1 | broome
# Processing Record 9 of Set 1 | bridlington
# Processing Record 10 of Set 1 | pisco
# Processing Record 11 of Set 1 | asmara
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | oxford
# Processing Record 14 of Set 1 | kamenka
# Processing Record 15 of Set 1 | la ronge
# Processing Record 16 of Set 1 | kenai
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | poum
# Processing Record 19 of Set 1 | nome
# Processing Record 20 of Set 1 | mar del plata
# Processing Record 21 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 1 | muros
# Processing Record 23 of Set 1 | hithadhoo
# Processing Record 24 of Set 1 | mount isa
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | butaritari
# Processing Record 27 of Set 1 | nemuro
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | allahabad
# Processing Record 30 of Set 1 | taoudenni
# Processing Record 31 of Set 1 | cherskiy
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | kajaani
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | port elizabeth
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | carnarvon
# Processing Record 38 of Set 1 | hilo
# Processing Record 39 of Set 1 | kiruna
# Processing Record 40 of Set 1 | zhangye
# Processing Record 41 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 1 | linchuan
# City not found. Skipping...
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | gushikawa
# Processing Record 46 of Set 1 | wattegama
# Processing Record 47 of Set 1 | aguimes
# Processing Record 48 of Set 1 | gualaquiza
# Processing Record 49 of Set 1 | pacific grove
# Processing Record 50 of Set 1 | masuda
# Processing Record 1 of Set 2 | yoichi
# Processing Record 2 of Set 2 | mahebourg
# Processing Record 3 of Set 2 | karlskoga
# Processing Record 4 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | asfi
# Processing Record 7 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 2 | tasiilaq
# Processing Record 9 of Set 2 | malgrat de mar
# Processing Record 10 of Set 2 | chuy
# Processing Record 11 of Set 2 | arraial do cabo
# Processing Record 12 of Set 2 | saint-philippe
# Processing Record 13 of Set 2 | sirfa
# City not found. Skipping...
# Processing Record 14 of Set 2 | jiangyou
# Processing Record 15 of Set 2 | victoria
# Processing Record 16 of Set 2 | la romana
# Processing Record 17 of Set 2 | vostok
# Processing Record 18 of Set 2 | hobart
# Processing Record 19 of Set 2 | coaldale
# Processing Record 20 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 2 | longyearbyen
# Processing Record 22 of Set 2 | talnakh
# Processing Record 23 of Set 2 | ostrovnoy
# Processing Record 24 of Set 2 | castro
# Processing Record 25 of Set 2 | konstantinovsk
# Processing Record 26 of Set 2 | comodoro rivadavia
# Processing Record 27 of Set 2 | fort nelson
# Processing Record 28 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 2 | linjiang
# Processing Record 30 of Set 2 | hermanus
# Processing Record 31 of Set 2 | bluff
# Processing Record 32 of Set 2 | ashdod
# Processing Record 33 of Set 2 | pueblo
# Processing Record 34 of Set 2 | kirakira
# Processing Record 35 of Set 2 | wawa
# Processing Record 36 of Set 2 | kaitangata
# Processing Record 37 of Set 2 | inirida
# Processing Record 38 of Set 2 | avarua
# Processing Record 39 of Set 2 | ahipara
# Processing Record 40 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 2 | east london
# Processing Record 42 of Set 2 | anadyr
# Processing Record 43 of Set 2 | whitehorse
# Processing Record 44 of Set 2 | airai
# Processing Record 45 of Set 2 | bouna
# Processing Record 46 of Set 2 | najran
# Processing Record 47 of Set 2 | pacifica
# Processing Record 48 of Set 2 | nikolskoye
# Processing Record 49 of Set 2 | katav-ivanovsk
# Processing Record 50 of Set 2 | hasaki
# Processing Record 1 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 3 | puerto ayora
# Processing Record 3 of Set 3 | menongue
# Processing Record 4 of Set 3 | geresk
# City not found. Skipping...
# Processing Record 5 of Set 3 | yaqui
# Processing Record 6 of Set 3 | port alfred
# Processing Record 7 of Set 3 | mbalmayo
# Processing Record 8 of Set 3 | tuktoyaktuk
# Processing Record 9 of Set 3 | salur
# Processing Record 10 of Set 3 | nova londrina
# Processing Record 11 of Set 3 | baracoa
# Processing Record 12 of Set 3 | tambopata
# Processing Record 13 of Set 3 | ceplenita
# Processing Record 14 of Set 3 | vastervik
# City not found. Skipping...
# Processing Record 15 of Set 3 | jamestown
# Processing Record 16 of Set 3 | milingimbi
# City not found. Skipping...
# Processing Record 17 of Set 3 | shasta lake
# Processing Record 18 of Set 3 | severo-kurilsk
# Processing Record 19 of Set 3 | kikwit
# Processing Record 20 of Set 3 | dikson
# Processing Record 21 of Set 3 | bowen
# Processing Record 22 of Set 3 | mount gambier
# Processing Record 23 of Set 3 | yellowknife
# Processing Record 24 of Set 3 | palmer
# Processing Record 25 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 3 | lisakovsk
# Processing Record 27 of Set 3 | provideniya
# Processing Record 28 of Set 3 | dingle
# Processing Record 29 of Set 3 | vanavara
# Processing Record 30 of Set 3 | pevek
# Processing Record 31 of Set 3 | ipora
# Processing Record 32 of Set 3 | shakawe
# Processing Record 33 of Set 3 | wum
# Processing Record 34 of Set 3 | caohe
# Processing Record 35 of Set 3 | kloulklubed
# Processing Record 36 of Set 3 | dunedin
# Processing Record 37 of Set 3 | kapaa
# Processing Record 38 of Set 3 | mehamn
# Processing Record 39 of Set 3 | naze
# Processing Record 40 of Set 3 | barrow
# Processing Record 41 of Set 3 | nizhniy ingash
# Processing Record 42 of Set 3 | petrosani
# Processing Record 43 of Set 3 | peru
# Processing Record 44 of Set 3 | fort walton beach
# Processing Record 45 of Set 3 | concepcion del oro
# Processing Record 46 of Set 3 | iqaluit
# Processing Record 47 of Set 3 | constitucion
# Processing Record 48 of Set 3 | puerto carreno
# Processing Record 49 of Set 3 | cidreira
# Processing Record 50 of Set 3 | leningradskiy
# Processing Record 1 of Set 4 | bandarbeyla
# Processing Record 2 of Set 4 | lebu
# Processing Record 3 of Set 4 | mahibadhoo
# Processing Record 4 of Set 4 | shimoda
# Processing Record 5 of Set 4 | koslan
# Processing Record 6 of Set 4 | notse
# Processing Record 7 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 8 of Set 4 | yar-sale
# Processing Record 9 of Set 4 | bredasdorp
# Processing Record 10 of Set 4 | itarema
# Processing Record 11 of Set 4 | begoro
# Processing Record 12 of Set 4 | chimore
# Processing Record 13 of Set 4 | portland
# Processing Record 14 of Set 4 | ponta do sol
# Processing Record 15 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 4 | davenda
# Processing Record 17 of Set 4 | bahir dar
# Processing Record 18 of Set 4 | gorontalo
# Processing Record 19 of Set 4 | hecun
# Processing Record 20 of Set 4 | laguna de perlas
# Processing Record 21 of Set 4 | thompson
# Processing Record 22 of Set 4 | ishimbay
# Processing Record 23 of Set 4 | aykino
# Processing Record 24 of Set 4 | college
# Processing Record 25 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 26 of Set 4 | boyolangu
# Processing Record 27 of Set 4 | chicama
# Processing Record 28 of Set 4 | vinces
# Processing Record 29 of Set 4 | bambous virieux
# Processing Record 30 of Set 4 | araouane
# Processing Record 31 of Set 4 | mastic beach
# Processing Record 32 of Set 4 | flinders
# Processing Record 33 of Set 4 | saint-augustin
# Processing Record 34 of Set 4 | sinnar
# Processing Record 35 of Set 4 | hami
# Processing Record 36 of Set 4 | atar
# Processing Record 37 of Set 4 | champerico
# Processing Record 38 of Set 4 | kaliua
# Processing Record 39 of Set 4 | ribeira grande
# Processing Record 40 of Set 4 | palauig
# Processing Record 41 of Set 4 | cabo san lucas
# Processing Record 42 of Set 4 | korla
# Processing Record 43 of Set 4 | kodiak
# Processing Record 44 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 4 | nanortalik
# Processing Record 46 of Set 4 | bairiki
# Processing Record 47 of Set 4 | padang
# Processing Record 48 of Set 4 | chalus
# Processing Record 49 of Set 4 | harer
# Processing Record 50 of Set 4 | kahului
# Processing Record 1 of Set 5 | nelson bay
# Processing Record 2 of Set 5 | half moon bay
# Processing Record 3 of Set 5 | ixtapa
# Processing Record 4 of Set 5 | crixas
# Processing Record 5 of Set 5 | bereda
# Processing Record 6 of Set 5 | syamzha
# Processing Record 7 of Set 5 | burnie
# Processing Record 8 of Set 5 | biala podlaska
# Processing Record 9 of Set 5 | gold coast
# Processing Record 10 of Set 5 | kampene
# Processing Record 11 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 5 | toowoomba
# Processing Record 14 of Set 5 | portobelo
# Processing Record 15 of Set 5 | chokurdakh
# Processing Record 16 of Set 5 | saint george
# Processing Record 17 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 5 | cloppenburg
# Processing Record 19 of Set 5 | huarmey
# Processing Record 20 of Set 5 | pizarro
# Processing Record 21 of Set 5 | opunake
# Processing Record 22 of Set 5 | te anau
# Processing Record 23 of Set 5 | clyde river
# Processing Record 24 of Set 5 | kulhudhuffushi
# Processing Record 25 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 5 | komsomolskiy
# Processing Record 27 of Set 5 | salinas
# Processing Record 28 of Set 5 | touros
# Processing Record 29 of Set 5 | rehoboth
# Processing Record 30 of Set 5 | sao filipe
# Processing Record 31 of Set 5 | brae
# Processing Record 32 of Set 5 | puerto escondido
# Processing Record 33 of Set 5 | honningsvag
# Processing Record 34 of Set 5 | taguatinga
# Processing Record 35 of Set 5 | labuhan
# Processing Record 36 of Set 5 | saldanha
# Processing Record 37 of Set 5 | gizo
# Processing Record 38 of Set 5 | methoni
# Processing Record 39 of Set 5 | mayo
# Processing Record 40 of Set 5 | winneba
# Processing Record 41 of Set 5 | bambanglipuro
# Processing Record 42 of Set 5 | alofi
# Processing Record 43 of Set 5 | fortuna
# Processing Record 44 of Set 5 | kpandae
# Processing Record 45 of Set 5 | ouargaye
# Processing Record 46 of Set 5 | koumac
# Processing Record 47 of Set 5 | razdolinsk
# Processing Record 48 of Set 5 | barcelos
# Processing Record 49 of Set 5 | glubokiy
# Processing Record 50 of Set 5 | mnogovershinnyy
# Processing Record 1 of Set 6 | nanaimo
# Processing Record 2 of Set 6 | maceio
# Processing Record 3 of Set 6 | bethel
# Processing Record 4 of Set 6 | natal
# Processing Record 5 of Set 6 | mogadishu
# Processing Record 6 of Set 6 | gouyave
# Processing Record 7 of Set 6 | oranjemund
# Processing Record 8 of Set 6 | kutum
# Processing Record 9 of Set 6 | kruisfontein
# Processing Record 10 of Set 6 | torbay
# Processing Record 11 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 6 | geraldton
# Processing Record 13 of Set 6 | lavrentiya
# Processing Record 14 of Set 6 | bathsheba
# Processing Record 15 of Set 6 | tuatapere
# Processing Record 16 of Set 6 | balikpapan
# Processing Record 17 of Set 6 | novopokrovka
# Processing Record 18 of Set 6 | takoradi
# Processing Record 19 of Set 6 | lasa
# Processing Record 20 of Set 6 | santarem
# Processing Record 21 of Set 6 | naryan-mar
# Processing Record 22 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 6 | ngunguru
# Processing Record 24 of Set 6 | ekibastuz
# Processing Record 25 of Set 6 | guelavia
# City not found. Skipping...
# Processing Record 26 of Set 6 | simoes
# Processing Record 27 of Set 6 | kapit
# Processing Record 28 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 29 of Set 6 | griffith
# Processing Record 30 of Set 6 | georgetown
# Processing Record 31 of Set 6 | ola
# Processing Record 32 of Set 6 | port lincoln
# Processing Record 33 of Set 6 | tupik
# Processing Record 34 of Set 6 | oostburg
# Processing Record 35 of Set 6 | khani
# Processing Record 36 of Set 6 | sinnamary
# Processing Record 37 of Set 6 | guerrero negro
# Processing Record 38 of Set 6 | awjilah
# Processing Record 39 of Set 6 | sitka
# Processing Record 40 of Set 6 | vagur
# Processing Record 41 of Set 6 | saskylakh
# Processing Record 42 of Set 6 | san patricio
# Processing Record 43 of Set 6 | deputatskiy
# Processing Record 44 of Set 6 | kisangani
# Processing Record 45 of Set 6 | soubre
# Processing Record 46 of Set 6 | qaanaaq
# Processing Record 47 of Set 6 | sorata
# Processing Record 48 of Set 6 | upernavik
# Processing Record 49 of Set 6 | beringovskiy
# Processing Record 50 of Set 6 | omsukchan
# Processing Record 1 of Set 7 | tiksi
# Processing Record 2 of Set 7 | dulce nombre de culmi
# Processing Record 3 of Set 7 | saint-cyr-sur-loire
# Processing Record 4 of Set 7 | kokopo
# Processing Record 5 of Set 7 | luderitz
# Processing Record 6 of Set 7 | lompoc
# Processing Record 7 of Set 7 | hofn
# Processing Record 8 of Set 7 | boa vista
# Processing Record 9 of Set 7 | camacari
# Processing Record 10 of Set 7 | hovd
# Processing Record 11 of Set 7 | rawson
# Processing Record 12 of Set 7 | mineiros
# Processing Record 13 of Set 7 | esperance
# Processing Record 14 of Set 7 | kharp
# Processing Record 15 of Set 7 | souillac
# Processing Record 16 of Set 7 | nuuk
# Processing Record 17 of Set 7 | los llanos de aridane
# Processing Record 18 of Set 7 | vanderhoof
# Processing Record 19 of Set 7 | marang
# Processing Record 20 of Set 7 | pundaguitan
# Processing Record 21 of Set 7 | ubauro
# Processing Record 22 of Set 7 | skovorodino
# Processing Record 23 of Set 7 | lander
# Processing Record 24 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 25 of Set 7 | ekhabi
# Processing Record 26 of Set 7 | pangnirtung
# Processing Record 27 of Set 7 | shipunovo
# Processing Record 28 of Set 7 | kushima
# Processing Record 29 of Set 7 | chernyshevskiy
# Processing Record 30 of Set 7 | shizunai
# Processing Record 31 of Set 7 | tecpan
# Processing Record 32 of Set 7 | faya
# Processing Record 33 of Set 7 | adzope
# Processing Record 34 of Set 7 | mandalgovi
# Processing Record 35 of Set 7 | riyadh
# Processing Record 36 of Set 7 | klaksvik
# Processing Record 37 of Set 7 | tual
# Processing Record 38 of Set 7 | mariinsk
# Processing Record 39 of Set 7 | namibe
# Processing Record 40 of Set 7 | briceni
# Processing Record 41 of Set 7 | mashhad
# Processing Record 42 of Set 7 | pochutla
# Processing Record 43 of Set 7 | seoul
# Processing Record 44 of Set 7 | baykit
# Processing Record 45 of Set 7 | hervey bay
# Processing Record 46 of Set 7 | faanui
# Processing Record 47 of Set 7 | marzuq
# Processing Record 48 of Set 7 | mamboma
# Processing Record 49 of Set 7 | sept-iles
# Processing Record 50 of Set 7 | port hedland
# Processing Record 1 of Set 8 | lazaro cardenas
# Processing Record 2 of Set 8 | oktyabrskiy
# Processing Record 3 of Set 8 | vila velha
# Processing Record 4 of Set 8 | nishihara
# Processing Record 5 of Set 8 | we
# City not found. Skipping...
# Processing Record 6 of Set 8 | auki
# Processing Record 7 of Set 8 | strai
# Processing Record 8 of Set 8 | agua verde
# Processing Record 9 of Set 8 | van wert
# Processing Record 10 of Set 8 | port moresby
# Processing Record 11 of Set 8 | bilibino
# Processing Record 12 of Set 8 | paita
# Processing Record 13 of Set 8 | bengkulu
# Processing Record 14 of Set 8 | maldonado
# Processing Record 15 of Set 8 | svetlaya
# Processing Record 16 of Set 8 | prince rupert
# Processing Record 17 of Set 8 | kincardine
# Processing Record 18 of Set 8 | narsaq
# Processing Record 19 of Set 8 | norman wells
# Processing Record 20 of Set 8 | cacu
# Processing Record 21 of Set 8 | koulamoutou
# Processing Record 22 of Set 8 | valparaiso
# Processing Record 23 of Set 8 | podporozhye
# Processing Record 24 of Set 8 | vitim
# Processing Record 25 of Set 8 | udachnyy
# Processing Record 26 of Set 8 | salalah
# Processing Record 27 of Set 8 | urumqi
# Processing Record 28 of Set 8 | aklavik
# Processing Record 29 of Set 8 | moron
# Processing Record 30 of Set 8 | carndonagh
# Processing Record 31 of Set 8 | sao joao da barra
# Processing Record 32 of Set 8 | ayoquezco
# City not found. Skipping...
# Processing Record 33 of Set 8 | isangel
# Processing Record 34 of Set 8 | manbij
# Processing Record 35 of Set 8 | merritt island
# Processing Record 36 of Set 8 | kyaikkami
# Processing Record 37 of Set 8 | yate
# Processing Record 38 of Set 8 | tete
# Processing Record 39 of Set 8 | belmonte
# Processing Record 40 of Set 8 | al
# City not found. Skipping...
# Processing Record 41 of Set 8 | karpogory
# Processing Record 42 of Set 8 | inuvik
# Processing Record 43 of Set 8 | sungaipenuh
# Processing Record 44 of Set 8 | clarence town
# Processing Record 45 of Set 8 | ketchikan
# Processing Record 46 of Set 8 | santa rosalia
# Processing Record 47 of Set 8 | hongjiang
# Processing Record 48 of Set 8 | the valley
# Processing Record 49 of Set 8 | farafangana
# Processing Record 50 of Set 8 | nantucket
# Processing Record 1 of Set 9 | rio gallegos
# Processing Record 2 of Set 9 | shahrud
# Processing Record 3 of Set 9 | mooi river
# City not found. Skipping...
# Processing Record 4 of Set 9 | wau
# Processing Record 5 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 6 of Set 9 | artesia
# Processing Record 7 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 8 of Set 9 | valkla
# Processing Record 9 of Set 9 | truro
# Processing Record 10 of Set 9 | boende
# Processing Record 11 of Set 9 | waipawa
# Processing Record 12 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 13 of Set 9 | stornoway
# Processing Record 14 of Set 9 | zhigansk
# Processing Record 15 of Set 9 | kijang
# Processing Record 16 of Set 9 | mumford
# Processing Record 17 of Set 9 | ancud
# Processing Record 18 of Set 9 | palia kalan
# Processing Record 19 of Set 9 | rumoi
# Processing Record 20 of Set 9 | kaka
# Processing Record 21 of Set 9 | katsuura
# Processing Record 22 of Set 9 | miyako
# Processing Record 23 of Set 9 | garchitorena
# Processing Record 24 of Set 9 | bonavista
# Processing Record 25 of Set 9 | vestmannaeyjar
# Processing Record 26 of Set 9 | cairns
# Processing Record 27 of Set 9 | qostanay
# Processing Record 28 of Set 9 | murray bridge
# Processing Record 29 of Set 9 | dorchester
# Processing Record 30 of Set 9 | ilulissat
# Processing Record 31 of Set 9 | kavieng
# Processing Record 32 of Set 9 | fairlie
# Processing Record 33 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 9 | ust-nera
# Processing Record 35 of Set 9 | lucapa
# Processing Record 36 of Set 9 | gibara
# Processing Record 37 of Set 9 | katherine
# Processing Record 38 of Set 9 | nyrob
# Processing Record 39 of Set 9 | golyshmanovo
# Processing Record 40 of Set 9 | aasiaat
# Processing Record 41 of Set 9 | teneguiban
# City not found. Skipping...
# Processing Record 42 of Set 9 | bell ville
# Processing Record 43 of Set 9 | tabas
# Processing Record 44 of Set 9 | ambanja
# Processing Record 45 of Set 9 | tobermory
# Processing Record 46 of Set 9 | mata
# Processing Record 47 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 48 of Set 9 | umm lajj
# Processing Record 49 of Set 9 | port macquarie
# Processing Record 50 of Set 9 | aykhal
# Processing Record 1 of Set 10 | senno
# Processing Record 2 of Set 10 | cervo
# Processing Record 3 of Set 10 | banda aceh
# Processing Record 4 of Set 10 | tigil
# Processing Record 5 of Set 10 | vila franca do campo
# Processing Record 6 of Set 10 | kaduqli
# Processing Record 7 of Set 10 | cayenne
# Processing Record 8 of Set 10 | novo oriente
# Processing Record 9 of Set 10 | shetpe
# Processing Record 10 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 11 of Set 10 | kasongo-lunda
# Processing Record 12 of Set 10 | kanker
# Processing Record 13 of Set 10 | gat
# Processing Record 14 of Set 10 | susuman
# Processing Record 15 of Set 10 | sambava
# Processing Record 16 of Set 10 | maniitsoq
# Processing Record 17 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 18 of Set 10 | sangar
# Processing Record 19 of Set 10 | port hardy
# Processing Record 20 of Set 10 | codrington
# Processing Record 21 of Set 10 | fairbanks
# Processing Record 22 of Set 10 | belyy yar
# Processing Record 23 of Set 10 | krasnoye
# Processing Record 24 of Set 10 | caravelas
# Processing Record 25 of Set 10 | tukrah
# Processing Record 26 of Set 10 | acari
# Processing Record 27 of Set 10 | bristol
# Processing Record 28 of Set 10 | matagami
# Processing Record 29 of Set 10 | magdagachi
# Processing Record 30 of Set 10 | maragogi
# Processing Record 31 of Set 10 | preobrazheniye
# Processing Record 32 of Set 10 | kabompo
# Processing Record 33 of Set 10 | ojinaga
# Processing Record 34 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 35 of Set 10 | coihaique
# Processing Record 36 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 10 | shrewsbury
# Processing Record 38 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 10 | talaya
# Processing Record 40 of Set 10 | sylvan lake
# Processing Record 41 of Set 10 | shelburne
# Processing Record 42 of Set 10 | broken hill
# Processing Record 43 of Set 10 | punta de bombon
# Processing Record 44 of Set 10 | swidnica
# Processing Record 45 of Set 10 | husavik
# Processing Record 46 of Set 10 | masakin
# Processing Record 47 of Set 10 | new ross
# Processing Record 48 of Set 10 | asayita
# City not found. Skipping...
# Processing Record 49 of Set 10 | tarakan
# Processing Record 50 of Set 10 | gueret
# Processing Record 1 of Set 11 | qaqortoq
# Processing Record 2 of Set 11 | atlantic city
# Processing Record 3 of Set 11 | linxia
# Processing Record 4 of Set 11 | maidens
# Processing Record 5 of Set 11 | tsogni
# Processing Record 6 of Set 11 | lagoa
# Processing Record 7 of Set 11 | bury saint edmunds
# City not found. Skipping...
# Processing Record 8 of Set 11 | semey
# Processing Record 9 of Set 11 | atherton
# Processing Record 10 of Set 11 | goderich
# Processing Record 11 of Set 11 | pocao de pedras
# Processing Record 12 of Set 11 | yarmouth
# Processing Record 13 of Set 11 | ciudad bolivar
# Processing Record 14 of Set 11 | avera
# Processing Record 15 of Set 11 | kyzyl-suu
# Processing Record 16 of Set 11 | hamilton
# Processing Record 17 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 11 | nokaneng
# Processing Record 19 of Set 11 | kuala terengganu
# Processing Record 20 of Set 11 | sobolevo
# Processing Record 21 of Set 11 | doka
# Processing Record 22 of Set 11 | coari
# Processing Record 23 of Set 11 | wang saphung
# Processing Record 24 of Set 11 | khilok
# Processing Record 25 of Set 11 | makakilo city
# Processing Record 26 of Set 11 | gympie
# Processing Record 27 of Set 11 | rafaela
# Processing Record 28 of Set 11 | san rafael
# Processing Record 29 of Set 11 | baisha
# Processing Record 30 of Set 11 | sibolga
# Processing Record 31 of Set 11 | krasnogorsk
# Processing Record 32 of Set 11 | yining
# Processing Record 33 of Set 11 | xining
# Processing Record 34 of Set 11 | asau
# Processing Record 35 of Set 11 | alugan
# Processing Record 36 of Set 11 | vao
# Processing Record 37 of Set 11 | atasu
# Processing Record 38 of Set 11 | coquimbo
# Processing Record 39 of Set 11 | rafai
# Processing Record 40 of Set 11 | graneros
# Processing Record 41 of Set 11 | qasigiannguit
# Processing Record 42 of Set 11 | hay river
# Processing Record 43 of Set 11 | kaspiyskiy
# Processing Record 44 of Set 11 | vanimo
# Processing Record 45 of Set 11 | daoukro
# Processing Record 46 of Set 11 | paamiut
# Processing Record 47 of Set 11 | bull savanna
# Processing Record 48 of Set 11 | san policarpo
# Processing Record 49 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 50 of Set 11 | dauphin
# Processing Record 1 of Set 12 | golden
# Processing Record 2 of Set 12 | fethiye
# Processing Record 3 of Set 12 | labuan
# Processing Record 4 of Set 12 | rio bueno
# Processing Record 5 of Set 12 | plettenberg bay
# Processing Record 6 of Set 12 | antalaha
# Processing Record 7 of Set 12 | namatanai
# Processing Record 8 of Set 12 | marsa matruh
# Processing Record 9 of Set 12 | tura
# Processing Record 10 of Set 12 | nieuw amsterdam
# Processing Record 11 of Set 12 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 12 of Set 12 | gornopravdinsk
# Processing Record 13 of Set 12 | yarega
# Processing Record 14 of Set 12 | fairview
# Processing Record 15 of Set 12 | bachaquero
# Processing Record 16 of Set 12 | nizhnyaya tavda
# Processing Record 17 of Set 12 | trinidad
# Processing Record 18 of Set 12 | harper
# Processing Record 19 of Set 12 | toora-khem
# Processing Record 20 of Set 12 | sedan
# Processing Record 21 of Set 12 | tazovskiy
# Processing Record 22 of Set 12 | rundu
# Processing Record 23 of Set 12 | churapcha
# Processing Record 24 of Set 12 | arica
# Processing Record 25 of Set 12 | san luis
# Processing Record 26 of Set 12 | asyut
# Processing Record 27 of Set 12 | cooma
# Processing Record 28 of Set 12 | kushmurun
# Processing Record 29 of Set 12 | touba
# Processing Record 30 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 31 of Set 12 | galle
# Processing Record 32 of Set 12 | paraiso
# Processing Record 33 of Set 12 | hambantota
# Processing Record 34 of Set 12 | pocone
# Processing Record 35 of Set 12 | celendin
# Processing Record 36 of Set 12 | cucer
# City not found. Skipping...
# Processing Record 37 of Set 12 | okhotsk
# Processing Record 38 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 39 of Set 12 | itapora
# Processing Record 40 of Set 12 | kandrian
# Processing Record 41 of Set 12 | kuybysheve
# Processing Record 42 of Set 12 | kerema
# Processing Record 43 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 44 of Set 12 | makung
# City not found. Skipping...
# Processing Record 45 of Set 12 | sur
# Processing Record 46 of Set 12 | juneau
# Processing Record 47 of Set 12 | sola
# Processing Record 48 of Set 12 | port-gentil
# Processing Record 49 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 50 of Set 12 | black river
# Processing Record 1 of Set 13 | saint-pierre
# Processing Record 2 of Set 13 | turinsk
# Processing Record 3 of Set 13 | cockburn town
# Processing Record 4 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 5 of Set 13 | bakuriani
# Processing Record 6 of Set 13 | mishan
# Processing Record 7 of Set 13 | concordia
# Processing Record 8 of Set 13 | waingapu
# Processing Record 9 of Set 13 | mayumba
# Processing Record 10 of Set 13 | vydrino
# Processing Record 11 of Set 13 | marfino
# Processing Record 12 of Set 13 | ust-maya
# Processing Record 13 of Set 13 | de-kastri
# Processing Record 14 of Set 13 | wegberg
# Processing Record 15 of Set 13 | bichis
# Processing Record 16 of Set 13 | biak
# Processing Record 17 of Set 13 | evensk
# Processing Record 18 of Set 13 | beyneu
# Processing Record 19 of Set 13 | vicuna
# Processing Record 20 of Set 13 | mayya
# Processing Record 21 of Set 13 | camacha
# Processing Record 22 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 23 of Set 13 | jinhua
# Processing Record 24 of Set 13 | garowe
# Processing Record 25 of Set 13 | tromso
# Processing Record 26 of Set 13 | noumea
# Processing Record 27 of Set 13 | beatrice
# Processing Record 28 of Set 13 | dalgopol
# Processing Record 29 of Set 13 | kindu
# Processing Record 30 of Set 13 | ibicarai
# Processing Record 31 of Set 13 | ozinki
# Processing Record 32 of Set 13 | guia de isora
# Processing Record 33 of Set 13 | constantine
# Processing Record 34 of Set 13 | verkhnevilyuysk
# Processing Record 35 of Set 13 | ascension
# Processing Record 36 of Set 13 | mendoza
# Processing Record 37 of Set 13 | christchurch
# Processing Record 38 of Set 13 | necochea
# Processing Record 39 of Set 13 | srednekolymsk
# Processing Record 40 of Set 13 | tocopilla
# Processing Record 41 of Set 13 | payakumbuh
# Processing Record 42 of Set 13 | sao paulo de olivenca
# Processing Record 43 of Set 13 | yulara
# Processing Record 44 of Set 13 | mount abu
# Processing Record 45 of Set 13 | kurilsk
# Processing Record 46 of Set 13 | goure
# Processing Record 47 of Set 13 | mattru
# Processing Record 48 of Set 13 | vila
# Processing Record 49 of Set 13 | wakkanai
# Processing Record 50 of Set 13 | birao
# Processing Record 1 of Set 14 | rafraf
# Processing Record 2 of Set 14 | lima
# Processing Record 3 of Set 14 | aleksandrovskoye
# Processing Record 4 of Set 14 | mindelo
# Processing Record 5 of Set 14 | flin flon
# Processing Record 6 of Set 14 | ochakiv
# Processing Record 7 of Set 14 | panzhihua
# Processing Record 8 of Set 14 | itambacuri
# Processing Record 9 of Set 14 | nsanje
# Processing Record 10 of Set 14 | roma
# Processing Record 11 of Set 14 | rabo de peixe
# Processing Record 12 of Set 14 | richards bay
# Processing Record 13 of Set 14 | torrington
# Processing Record 14 of Set 14 | erenhot
# Processing Record 15 of Set 14 | litovko
# Processing Record 16 of Set 14 | havoysund
# Processing Record 17 of Set 14 | ukiah
# Processing Record 18 of Set 14 | kuminskiy
# Processing Record 19 of Set 14 | russell
# Processing Record 20 of Set 14 | dukat
# Processing Record 21 of Set 14 | sovetskiy
# Processing Record 22 of Set 14 | dwarka
# Processing Record 23 of Set 14 | oranjestad
# Processing Record 24 of Set 14 | kieta
# Processing Record 25 of Set 14 | rio grande
# Processing Record 26 of Set 14 | itoman
# Processing Record 27 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 28 of Set 14 | samfya
# Processing Record 29 of Set 14 | guelengdeng
# City not found. Skipping...
# Processing Record 30 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 32 of Set 14 | sironko
# Processing Record 33 of Set 14 | mizque
# Processing Record 34 of Set 14 | balakhta
# Processing Record 35 of Set 14 | laem sing
# Processing Record 36 of Set 14 | silvania
# Processing Record 37 of Set 14 | brokopondo
# Processing Record 38 of Set 14 | mirabad
# Processing Record 39 of Set 14 | bontang
# Processing Record 40 of Set 14 | grand gaube
# Processing Record 41 of Set 14 | dese
# Processing Record 42 of Set 14 | anito
# Processing Record 43 of Set 14 | bijie
# Processing Record 44 of Set 14 | kazerun
# Processing Record 45 of Set 14 | abu samrah
# Processing Record 46 of Set 14 | montgomery
# Processing Record 47 of Set 14 | kununurra
# Processing Record 48 of Set 14 | buraydah
# Processing Record 49 of Set 14 | baruun-urt
# Processing Record 50 of Set 14 | brigantine
# Processing Record 1 of Set 15 | huilong
# Processing Record 2 of Set 15 | ust-omchug
# Processing Record 3 of Set 15 | vokhma
# Processing Record 4 of Set 15 | harrisburg
# Processing Record 5 of Set 15 | kafue
# Processing Record 6 of Set 15 | ambilobe
# Processing Record 7 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 8 of Set 15 | guatire
# Processing Record 9 of Set 15 | venice
# Processing Record 10 of Set 15 | inta
# Processing Record 11 of Set 15 | huazolotitlan
# City not found. Skipping...
# Processing Record 12 of Set 15 | arlington
# Processing Record 13 of Set 15 | oktyabrskoye
# Processing Record 14 of Set 15 | chapais
# Processing Record 15 of Set 15 | tsimlyansk
# Processing Record 16 of Set 15 | beira
# Processing Record 17 of Set 15 | tilichiki
# Processing Record 18 of Set 15 | tiarei
# Processing Record 19 of Set 15 | barao de melgaco
# Processing Record 20 of Set 15 | calvia
# Processing Record 21 of Set 15 | yinchuan
# Processing Record 22 of Set 15 | san mateo del mar
# Processing Record 23 of Set 15 | tuy hoa
# Processing Record 24 of Set 15 | eydhafushi
# Processing Record 25 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 26 of Set 15 | bosaso
# Processing Record 27 of Set 15 | margate
# Processing Record 28 of Set 15 | san cristobal
# Processing Record 29 of Set 15 | tumen
# Processing Record 30 of Set 15 | northam
# Processing Record 31 of Set 15 | thai binh
# Processing Record 32 of Set 15 | kavaratti
# Processing Record 33 of Set 15 | yarada
# Processing Record 34 of Set 15 | nhulunbuy
# Processing Record 35 of Set 15 | talcahuano
# Processing Record 36 of Set 15 | yerbogachen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': 108.0108, 'lat': 61.2767},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 13.87,
#   'feels_like': 0.52,
#   'temp_min': 13.87,
#   'temp_max': 13.87,
#   'pressure': 1007,
#   'humidity': 94,
#   'sea_level': 1007,
#   'grnd_level': 971},
#  'visibility': 2976,
#  'wind': {'speed': 13.73, 'deg': 279},
#  'clouds': {'all': 90},
#  'dt': 1615173947,
#  'sys': {'country': 'RU', 'sunrise': 1615159686, 'sunset': 1615199385},
#  'timezone': 28800,
#  'id': 2012956,
#  'name': 'Yerbogachën',
#  'cod': 200}

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

#Reorder columns: City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, & Description
new_column_order = ["City", "Country", "Lat", "Lng", 
                    "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

#Assign new column order to DF
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                        City Country      Lat       Lng  Max Temp  Humidity  \
# 0                   Rikitea      PF -23.1203 -134.9692     79.88        83
# 1                 Yeniseysk      RU  58.4497   92.1703     15.87        96
# 2                     Arlit      NE  18.7369    7.3853     76.19        17
# 3                  Khatanga      RU  71.9667  102.5000    -26.61        85
# 4                     Yumen      CN  40.2833   97.2000     43.75        50
# 5  Sao Jose Da Coroa Grande      BR  -8.8978  -35.1478     77.65        85
# 6                    Broome      US  42.2506  -75.8330     17.60        53
# 7               Bridlington      GB  54.0831   -0.1919     39.00        86
# 8                     Pisco      PE -13.7000  -76.2167     72.00        83
# 9                    Asmara      ER  15.3333   38.9333     55.33        56
#
#    Cloudiness  Wind Speed Current Description
# 0         100       19.35       moderate rain
# 1          82        5.66       broken clouds
# 2           0       10.00           clear sky
# 3          90        2.08     overcast clouds
# 4           2       15.52           clear sky
# 5           6        7.11           clear sky
# 6           1        6.91           clear sky
# 7          99       10.42     overcast clouds
# 8           0       10.36           clear sky
# 9          39        1.92    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
