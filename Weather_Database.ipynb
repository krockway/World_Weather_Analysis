# %%
import pandas as pd
import gmaps
import requests
import matplotlib.pyplot as plt
import numpy as np

# Import the API key.
import sys
sys.path.insert(1,"../")
from config import g_key
from config import weather_api_key
from citipy import citipy
from datetime import datetime

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
#zip them together
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
#enumerate will get the index of the city for logging purposes & the city for creating the URL

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
        #(" ","+") means that it will remove spaces from city name & replace with +

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except KeyError:
        print("City not found. Skipping...")
        pass
            #Pass should be avoided
            #This means stop here and start back at the top, don't print the next line


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nikolskoye
# Processing Record 2 of Set 1 | nongan
# Processing Record 3 of Set 1 | esperance
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | okha
# Processing Record 8 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 1 | eureka
# Processing Record 10 of Set 1 | asau
# Processing Record 11 of Set 1 | akyab
# Processing Record 12 of Set 1 | saint-philippe
# Processing Record 13 of Set 1 | kavaratti
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | karakendzha
# City not found. Skipping...
# Processing Record 16 of Set 1 | mahebourg
# Processing Record 17 of Set 1 | ardistan
# City not found. Skipping...
# Processing Record 18 of Set 1 | sivas
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | pangai
# Processing Record 21 of Set 1 | smithers
# Processing Record 22 of Set 1 | pershotravneve
# Processing Record 23 of Set 1 | ridgecrest
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | marsabit
# Processing Record 26 of Set 1 | tasiilaq
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | lipin bor
# Processing Record 31 of Set 1 | satwas
# Processing Record 32 of Set 1 | sibolga
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | yei
# Processing Record 36 of Set 1 | kahului
# Processing Record 37 of Set 1 | tepatitlan
# City not found. Skipping...
# Processing Record 38 of Set 1 | teguldet
# Processing Record 39 of Set 1 | union city
# Processing Record 40 of Set 1 | kapaa
# Processing Record 41 of Set 1 | luba
# Processing Record 42 of Set 1 | uvat
# Processing Record 43 of Set 1 | opuwo
# Processing Record 44 of Set 1 | bathsheba
# Processing Record 45 of Set 1 | tuktoyaktuk
# Processing Record 46 of Set 1 | hare bay
# Processing Record 47 of Set 1 | mufumbwe
# Processing Record 48 of Set 1 | singapore
# Processing Record 49 of Set 1 | pasighat
# Processing Record 50 of Set 1 | thompson
# Processing Record 1 of Set 2 | bangolo
# Processing Record 2 of Set 2 | new norfolk
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | pacific grove
# Processing Record 6 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 2 | zajecar
# Processing Record 8 of Set 2 | nara
# Processing Record 9 of Set 2 | porto novo
# Processing Record 10 of Set 2 | kruisfontein
# Processing Record 11 of Set 2 | ribeira grande
# Processing Record 12 of Set 2 | qaanaaq
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | cabo san lucas
# Processing Record 15 of Set 2 | pevek
# Processing Record 16 of Set 2 | pisco
# Processing Record 17 of Set 2 | norman wells
# Processing Record 18 of Set 2 | mar del plata
# Processing Record 19 of Set 2 | ponta do sol
# Processing Record 20 of Set 2 | padang
# Processing Record 21 of Set 2 | ostrovnoy
# Processing Record 22 of Set 2 | avarua
# Processing Record 23 of Set 2 | faanui
# Processing Record 24 of Set 2 | chokurdakh
# Processing Record 25 of Set 2 | aquiraz
# Processing Record 26 of Set 2 | emba
# Processing Record 27 of Set 2 | belmonte
# Processing Record 28 of Set 2 | mataura
# Processing Record 29 of Set 2 | kontagora
# Processing Record 30 of Set 2 | la roche-sur-yon
# Processing Record 31 of Set 2 | lebu
# Processing Record 32 of Set 2 | husavik
# Processing Record 33 of Set 2 | salalah
# Processing Record 34 of Set 2 | albany
# Processing Record 35 of Set 2 | luganville
# Processing Record 36 of Set 2 | cape town
# Processing Record 37 of Set 2 | tura
# Processing Record 38 of Set 2 | naliya
# Processing Record 39 of Set 2 | carnarvon
# Processing Record 40 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 2 | oktyabrskoye
# Processing Record 42 of Set 2 | cidreira
# Processing Record 43 of Set 2 | bluff
# Processing Record 44 of Set 2 | bethel
# Processing Record 45 of Set 2 | lagoa
# Processing Record 46 of Set 2 | santiago del estero
# Processing Record 47 of Set 2 | kaitangata
# Processing Record 48 of Set 2 | antofagasta
# Processing Record 49 of Set 2 | mitsamiouli
# Processing Record 50 of Set 2 | una
# Processing Record 1 of Set 3 | broome
# Processing Record 2 of Set 3 | weyburn
# Processing Record 3 of Set 3 | bolobo
# Processing Record 4 of Set 3 | safaqis
# City not found. Skipping...
# Processing Record 5 of Set 3 | narsaq
# Processing Record 6 of Set 3 | san cristobal
# Processing Record 7 of Set 3 | beringovskiy
# Processing Record 8 of Set 3 | bambous virieux
# Processing Record 9 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 10 of Set 3 | pervomayskiy
# Processing Record 11 of Set 3 | flin flon
# Processing Record 12 of Set 3 | faya
# Processing Record 13 of Set 3 | barrow
# Processing Record 14 of Set 3 | prieska
# Processing Record 15 of Set 3 | saldanha
# Processing Record 16 of Set 3 | san lorenzo
# Processing Record 17 of Set 3 | haines junction
# Processing Record 18 of Set 3 | sitka
# Processing Record 19 of Set 3 | amahai
# Processing Record 20 of Set 3 | coolum beach
# Processing Record 21 of Set 3 | tiksi
# Processing Record 22 of Set 3 | daru
# Processing Record 23 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 3 | morden
# Processing Record 26 of Set 3 | namatanai
# Processing Record 27 of Set 3 | lodja
# Processing Record 28 of Set 3 | oussouye
# Processing Record 29 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 3 | uppsala
# Processing Record 31 of Set 3 | carutapera
# Processing Record 32 of Set 3 | den helder
# Processing Record 33 of Set 3 | gizo
# Processing Record 34 of Set 3 | dingle
# Processing Record 35 of Set 3 | ambon
# Processing Record 36 of Set 3 | katsuura
# Processing Record 37 of Set 3 | chuy
# Processing Record 38 of Set 3 | castlegar
# Processing Record 39 of Set 3 | khatanga
# Processing Record 40 of Set 3 | vardo
# Processing Record 41 of Set 3 | san fernando
# Processing Record 42 of Set 3 | castro
# Processing Record 43 of Set 3 | hilo
# Processing Record 44 of Set 3 | tiarei
# Processing Record 45 of Set 3 | tarbert
# Processing Record 46 of Set 3 | urusha
# Processing Record 47 of Set 3 | imeni poliny osipenko
# Processing Record 48 of Set 3 | zakamensk
# Processing Record 49 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 50 of Set 3 | cabra
# Processing Record 1 of Set 4 | canton
# Processing Record 2 of Set 4 | arraial do cabo
# Processing Record 3 of Set 4 | ugoofaaru
# Processing Record 4 of Set 4 | karratha
# Processing Record 5 of Set 4 | kurduvadi
# Processing Record 6 of Set 4 | longyearbyen
# Processing Record 7 of Set 4 | nianzishan
# Processing Record 8 of Set 4 | port hedland
# Processing Record 9 of Set 4 | inirida
# Processing Record 10 of Set 4 | vila velha
# Processing Record 11 of Set 4 | coahuayana
# Processing Record 12 of Set 4 | georgetown
# Processing Record 13 of Set 4 | asyut
# Processing Record 14 of Set 4 | mackay
# Processing Record 15 of Set 4 | coihaique
# Processing Record 16 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 4 | smoljan
# Processing Record 18 of Set 4 | christchurch
# Processing Record 19 of Set 4 | gonc
# Processing Record 20 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 4 | kavieng
# Processing Record 22 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 4 | korcula
# Processing Record 24 of Set 4 | sao filipe
# Processing Record 25 of Set 4 | dunmore town
# Processing Record 26 of Set 4 | margate
# Processing Record 27 of Set 4 | tuatapere
# Processing Record 28 of Set 4 | hualmay
# Processing Record 29 of Set 4 | wageningen
# Processing Record 30 of Set 4 | los llanos de aridane
# Processing Record 31 of Set 4 | sept-iles
# Processing Record 32 of Set 4 | ormara
# Processing Record 33 of Set 4 | jorochito
# Processing Record 34 of Set 4 | dikson
# Processing Record 35 of Set 4 | comodoro rivadavia
# Processing Record 36 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 4 | camacha
# Processing Record 38 of Set 4 | makakilo city
# Processing Record 39 of Set 4 | severo-kurilsk
# Processing Record 40 of Set 4 | formosa
# Processing Record 41 of Set 4 | teya
# Processing Record 42 of Set 4 | hobyo
# Processing Record 43 of Set 4 | pokhara
# Processing Record 44 of Set 4 | souillac
# Processing Record 45 of Set 4 | west wendover
# Processing Record 46 of Set 4 | show low
# Processing Record 47 of Set 4 | egvekinot
# Processing Record 48 of Set 4 | kapasan
# Processing Record 49 of Set 4 | kolpny
# Processing Record 50 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 5 | clyde river
# Processing Record 2 of Set 5 | tomatlan
# Processing Record 3 of Set 5 | corn island
# Processing Record 4 of Set 5 | harper
# Processing Record 5 of Set 5 | iqaluit
# Processing Record 6 of Set 5 | mtsensk
# Processing Record 7 of Set 5 | grindavik
# Processing Record 8 of Set 5 | hofn
# Processing Record 9 of Set 5 | karaton
# Processing Record 10 of Set 5 | airai
# Processing Record 11 of Set 5 | nioro
# Processing Record 12 of Set 5 | duki
# Processing Record 13 of Set 5 | ryotsu
# Processing Record 14 of Set 5 | kouango
# Processing Record 15 of Set 5 | vestmannaeyjar
# Processing Record 16 of Set 5 | rumonge
# Processing Record 17 of Set 5 | fort nelson
# Processing Record 18 of Set 5 | boa vista
# Processing Record 19 of Set 5 | high rock
# Processing Record 20 of Set 5 | nieves
# Processing Record 21 of Set 5 | milkovo
# Processing Record 22 of Set 5 | lavrentiya
# Processing Record 23 of Set 5 | turukhansk
# Processing Record 24 of Set 5 | kraslava
# Processing Record 25 of Set 5 | chernyshevskiy
# Processing Record 26 of Set 5 | birjand
# Processing Record 27 of Set 5 | constitucion
# Processing Record 28 of Set 5 | tutoia
# Processing Record 29 of Set 5 | lompoc
# Processing Record 30 of Set 5 | victoria
# Processing Record 31 of Set 5 | coquimbo
# Processing Record 32 of Set 5 | port elizabeth
# Processing Record 33 of Set 5 | bandarbeyla
# Processing Record 34 of Set 5 | sabha
# Processing Record 35 of Set 5 | solenzo
# Processing Record 36 of Set 5 | luderitz
# Processing Record 37 of Set 5 | east london
# Processing Record 38 of Set 5 | anda
# Processing Record 39 of Set 5 | eyl
# Processing Record 40 of Set 5 | tibiri
# Processing Record 41 of Set 5 | flinders
# Processing Record 42 of Set 5 | bilibino
# Processing Record 43 of Set 5 | mae ramat
# Processing Record 44 of Set 5 | aklavik
# Processing Record 45 of Set 5 | altamira
# Processing Record 46 of Set 5 | dunedin
# Processing Record 47 of Set 5 | san jose
# Processing Record 48 of Set 5 | hithadhoo
# Processing Record 49 of Set 5 | hervey bay
# Processing Record 50 of Set 5 | ocho rios
# Processing Record 1 of Set 6 | menongue
# Processing Record 2 of Set 6 | oranjemund
# Processing Record 3 of Set 6 | waddan
# Processing Record 4 of Set 6 | richards bay
# Processing Record 5 of Set 6 | zyryanka
# Processing Record 6 of Set 6 | renqiu
# Processing Record 7 of Set 6 | nome
# Processing Record 8 of Set 6 | kathu
# Processing Record 9 of Set 6 | bihoro
# Processing Record 10 of Set 6 | chapais
# Processing Record 11 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 6 | yeppoon
# Processing Record 13 of Set 6 | saint-georges
# Processing Record 14 of Set 6 | ofaqim
# Processing Record 15 of Set 6 | inuvik
# Processing Record 16 of Set 6 | victor harbor
# Processing Record 17 of Set 6 | hay river
# Processing Record 18 of Set 6 | sakaraha
# Processing Record 19 of Set 6 | upernavik
# Processing Record 20 of Set 6 | cayenne
# Processing Record 21 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 22 of Set 6 | northam
# Processing Record 23 of Set 6 | swamimalai
# Processing Record 24 of Set 6 | marawi
# Processing Record 25 of Set 6 | acari
# Processing Record 26 of Set 6 | kuzhithurai
# Processing Record 27 of Set 6 | dwarka
# Processing Record 28 of Set 6 | san quintin
# Processing Record 29 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 6 | lakselv
# Processing Record 31 of Set 6 | zatoka
# Processing Record 32 of Set 6 | tacoronte
# Processing Record 33 of Set 6 | sosnovo-ozerskoye
# Processing Record 34 of Set 6 | fortuna
# Processing Record 35 of Set 6 | chingola
# Processing Record 36 of Set 6 | buala
# Processing Record 37 of Set 6 | soyo
# Processing Record 38 of Set 6 | provideniya
# Processing Record 39 of Set 6 | codrington
# Processing Record 40 of Set 6 | kayan
# Processing Record 41 of Set 6 | saskylakh
# Processing Record 42 of Set 6 | thinadhoo
# Processing Record 43 of Set 6 | bow island
# Processing Record 44 of Set 6 | tukan
# Processing Record 45 of Set 6 | nishihara
# Processing Record 46 of Set 6 | tuy hoa
# Processing Record 47 of Set 6 | yaan
# Processing Record 48 of Set 6 | vila franca do campo
# Processing Record 49 of Set 6 | walvis bay
# Processing Record 50 of Set 6 | rzhev
# Processing Record 1 of Set 7 | derazhnya
# Processing Record 2 of Set 7 | isangel
# Processing Record 3 of Set 7 | alpena
# Processing Record 4 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 7 | areia branca
# Processing Record 6 of Set 7 | qinzhou
# Processing Record 7 of Set 7 | kearney
# Processing Record 8 of Set 7 | mehamn
# Processing Record 9 of Set 7 | lasa
# Processing Record 10 of Set 7 | tazovskiy
# Processing Record 11 of Set 7 | rio grande
# Processing Record 12 of Set 7 | lorengau
# Processing Record 13 of Set 7 | schweinfurt
# Processing Record 14 of Set 7 | resistencia
# Processing Record 15 of Set 7 | ningan
# City not found. Skipping...
# Processing Record 16 of Set 7 | duz
# City not found. Skipping...
# Processing Record 17 of Set 7 | rovnoye
# Processing Record 18 of Set 7 | burnie
# Processing Record 19 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 20 of Set 7 | krasnyy
# Processing Record 21 of Set 7 | palu
# Processing Record 22 of Set 7 | bubaque
# Processing Record 23 of Set 7 | xianshuigu
# Processing Record 24 of Set 7 | boshnyakovo
# Processing Record 25 of Set 7 | axim
# Processing Record 26 of Set 7 | heihe
# Processing Record 27 of Set 7 | north bend
# Processing Record 28 of Set 7 | bud
# Processing Record 29 of Set 7 | geraldton
# Processing Record 30 of Set 7 | wattegama
# Processing Record 31 of Set 7 | teguise
# Processing Record 32 of Set 7 | tahta
# Processing Record 33 of Set 7 | kidal
# Processing Record 34 of Set 7 | san policarpo
# Processing Record 35 of Set 7 | gandajika
# Processing Record 36 of Set 7 | fort walton beach
# Processing Record 37 of Set 7 | saint anthony
# Processing Record 38 of Set 7 | beachwood
# Processing Record 39 of Set 7 | sobolevo
# Processing Record 40 of Set 7 | westport
# Processing Record 41 of Set 7 | tahara
# Processing Record 42 of Set 7 | vestmanna
# Processing Record 43 of Set 7 | torbay
# Processing Record 44 of Set 7 | mazara del vallo
# Processing Record 45 of Set 7 | adigeni
# Processing Record 46 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 47 of Set 7 | cap malheureux
# Processing Record 48 of Set 7 | astana
# Processing Record 49 of Set 7 | ust-tsilma
# Processing Record 50 of Set 7 | fort-shevchenko
# Processing Record 1 of Set 8 | havre-saint-pierre
# Processing Record 2 of Set 8 | kodiak
# Processing Record 3 of Set 8 | marsa matruh
# Processing Record 4 of Set 8 | vila
# Processing Record 5 of Set 8 | port macquarie
# Processing Record 6 of Set 8 | nova olinda do norte
# Processing Record 7 of Set 8 | avera
# Processing Record 8 of Set 8 | gillette
# Processing Record 9 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 10 of Set 8 | ondjiva
# Processing Record 11 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 8 | melfi
# Processing Record 13 of Set 8 | satinka
# Processing Record 14 of Set 8 | broken hill
# Processing Record 15 of Set 8 | maningrida
# Processing Record 16 of Set 8 | owensboro
# Processing Record 17 of Set 8 | mugur-aksy
# Processing Record 18 of Set 8 | zelenets
# Processing Record 19 of Set 8 | port lincoln
# Processing Record 20 of Set 8 | najran
# Processing Record 21 of Set 8 | komsomolskiy
# Processing Record 22 of Set 8 | belaya gora
# Processing Record 23 of Set 8 | ancud
# Processing Record 24 of Set 8 | shubarkuduk
# Processing Record 25 of Set 8 | ponta delgada
# Processing Record 26 of Set 8 | cherskiy
# Processing Record 27 of Set 8 | kisesa
# Processing Record 28 of Set 8 | shimoda
# Processing Record 29 of Set 8 | dubbo
# Processing Record 30 of Set 8 | beyneu
# Processing Record 31 of Set 8 | senneterre
# Processing Record 32 of Set 8 | santa rosalia
# Processing Record 33 of Set 8 | laguna
# Processing Record 34 of Set 8 | acapulco
# Processing Record 35 of Set 8 | mabaruma
# Processing Record 36 of Set 8 | bengkulu
# Processing Record 37 of Set 8 | caala
# Processing Record 38 of Set 8 | pasni
# Processing Record 39 of Set 8 | port said
# Processing Record 40 of Set 8 | tessalit
# Processing Record 41 of Set 8 | acarau
# Processing Record 42 of Set 8 | teknaf
# Processing Record 43 of Set 8 | guadalupe
# Processing Record 44 of Set 8 | vrangel
# Processing Record 45 of Set 8 | nortelandia
# Processing Record 46 of Set 8 | port hardy
# Processing Record 47 of Set 8 | tautira
# Processing Record 48 of Set 8 | touros
# Processing Record 49 of Set 8 | chantilly
# Processing Record 50 of Set 8 | caxito
# Processing Record 1 of Set 9 | saint-pierre
# Processing Record 2 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 3 of Set 9 | sun valley
# Processing Record 4 of Set 9 | venice
# Processing Record 5 of Set 9 | peniche
# Processing Record 6 of Set 9 | salto del guaira
# Processing Record 7 of Set 9 | leningradskiy
# Processing Record 8 of Set 9 | talnakh
# Processing Record 9 of Set 9 | sokoni
# Processing Record 10 of Set 9 | nieuw amsterdam
# Processing Record 11 of Set 9 | qaqortoq
# Processing Record 12 of Set 9 | kulgam
# Processing Record 13 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 9 | nizhniy kuranakh
# Processing Record 15 of Set 9 | poum
# Processing Record 16 of Set 9 | seoul
# Processing Record 17 of Set 9 | chippewa falls
# Processing Record 18 of Set 9 | thunder bay
# Processing Record 19 of Set 9 | termiz
# Processing Record 20 of Set 9 | potanino
# Processing Record 21 of Set 9 | batemans bay
# Processing Record 22 of Set 9 | new bern
# Processing Record 23 of Set 9 | balabac
# Processing Record 24 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 9 | langfang
# Processing Record 26 of Set 9 | bria
# Processing Record 27 of Set 9 | candolim
# Processing Record 28 of Set 9 | aosta
# Processing Record 29 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 9 | nanortalik
# Processing Record 31 of Set 9 | othonoi
# City not found. Skipping...
# Processing Record 32 of Set 9 | anzio
# Processing Record 33 of Set 9 | deming
# Processing Record 34 of Set 9 | bauchi
# Processing Record 35 of Set 9 | boueni
# Processing Record 36 of Set 9 | krasnoselkup
# Processing Record 37 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 9 | esso
# Processing Record 39 of Set 9 | fairbanks
# Processing Record 40 of Set 9 | puerto escondido
# Processing Record 41 of Set 9 | emborion
# Processing Record 42 of Set 9 | turkistan
# Processing Record 43 of Set 9 | clearwater
# Processing Record 44 of Set 9 | vilcun
# Processing Record 45 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 9 | banda aceh
# Processing Record 47 of Set 9 | ambilobe
# Processing Record 48 of Set 9 | mega
# Processing Record 49 of Set 9 | kondinskoye
# Processing Record 50 of Set 9 | chimore
# Processing Record 1 of Set 10 | ouesso
# Processing Record 2 of Set 10 | tommot
# Processing Record 3 of Set 10 | gloversville
# Processing Record 4 of Set 10 | simao
# Processing Record 5 of Set 10 | kailua
# Processing Record 6 of Set 10 | bhum
# Processing Record 7 of Set 10 | whitehorse
# Processing Record 8 of Set 10 | mana
# Processing Record 9 of Set 10 | novopokrovka
# Processing Record 10 of Set 10 | kirakira
# Processing Record 11 of Set 10 | la ronge
# Processing Record 12 of Set 10 | port-gentil
# Processing Record 13 of Set 10 | hamilton
# Processing Record 14 of Set 10 | ilulissat
# Processing Record 15 of Set 10 | zhigansk
# Processing Record 16 of Set 10 | jijiga
# Processing Record 17 of Set 10 | te anau
# Processing Record 18 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 10 | pangnirtung
# Processing Record 20 of Set 10 | svetlogorsk
# Processing Record 21 of Set 10 | kalmunai
# Processing Record 22 of Set 10 | atar
# Processing Record 23 of Set 10 | mount isa
# Processing Record 24 of Set 10 | nynashamn
# Processing Record 25 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 10 | solnechnyy
# Processing Record 27 of Set 10 | sorland
# Processing Record 28 of Set 10 | itoman
# Processing Record 29 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 10 | suhbaatar
# Processing Record 31 of Set 10 | harnosand
# Processing Record 32 of Set 10 | socorro
# Processing Record 33 of Set 10 | cabedelo
# Processing Record 34 of Set 10 | gorele
# Processing Record 35 of Set 10 | kamenka
# Processing Record 36 of Set 10 | sampit
# Processing Record 37 of Set 10 | cuamba
# Processing Record 38 of Set 10 | kopong
# Processing Record 39 of Set 10 | alenquer
# Processing Record 40 of Set 10 | marrakesh
# Processing Record 41 of Set 10 | kiama
# Processing Record 42 of Set 10 | samarai
# Processing Record 43 of Set 10 | atyrau
# Processing Record 44 of Set 10 | angoche
# Processing Record 45 of Set 10 | berlevag
# Processing Record 46 of Set 10 | sanming
# Processing Record 47 of Set 10 | klaksvik
# Processing Record 48 of Set 10 | vao
# Processing Record 49 of Set 10 | umm lajj
# Processing Record 50 of Set 10 | lysyye gory
# Processing Record 1 of Set 11 | yulara
# Processing Record 2 of Set 11 | zaykovo
# Processing Record 3 of Set 11 | shache
# Processing Record 4 of Set 11 | monrovia
# Processing Record 5 of Set 11 | barranca
# Processing Record 6 of Set 11 | nenjiang
# Processing Record 7 of Set 11 | deputatskiy
# Processing Record 8 of Set 11 | gornyy
# Processing Record 9 of Set 11 | larkollen
# Processing Record 10 of Set 11 | ukiah
# Processing Record 11 of Set 11 | salme
# Processing Record 12 of Set 11 | isnos
# Processing Record 13 of Set 11 | carballo
# Processing Record 14 of Set 11 | mezen
# Processing Record 15 of Set 11 | kerchevskiy
# Processing Record 16 of Set 11 | aswan
# Processing Record 17 of Set 11 | hampton
# Processing Record 18 of Set 11 | rosita
# Processing Record 19 of Set 11 | ust-karsk
# Processing Record 20 of Set 11 | morondava
# Processing Record 21 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 22 of Set 11 | koygorodok
# Processing Record 23 of Set 11 | pekan
# Processing Record 24 of Set 11 | hasaki
# Processing Record 25 of Set 11 | stromness
# Processing Record 26 of Set 11 | gushikawa
# Processing Record 27 of Set 11 | kimbe
# Processing Record 28 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 29 of Set 11 | santa rosa
# Processing Record 30 of Set 11 | dzaoudzi
# Processing Record 31 of Set 11 | delvada
# Processing Record 32 of Set 11 | mokrousovo
# Processing Record 33 of Set 11 | taoudenni
# Processing Record 34 of Set 11 | hailar
# Processing Record 35 of Set 11 | severo-yeniseyskiy
# Processing Record 36 of Set 11 | san gavino monreale
# Processing Record 37 of Set 11 | kutum
# Processing Record 38 of Set 11 | moron
# Processing Record 39 of Set 11 | pleasanton
# Processing Record 40 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 42 of Set 11 | aasiaat
# Processing Record 43 of Set 11 | diffa
# Processing Record 44 of Set 11 | namibe
# Processing Record 45 of Set 11 | ksenyevka
# City not found. Skipping...
# Processing Record 46 of Set 11 | port pirie
# Processing Record 47 of Set 11 | sao felix do xingu
# Processing Record 48 of Set 11 | lata
# Processing Record 49 of Set 11 | auki
# Processing Record 50 of Set 11 | maneromango
# Processing Record 1 of Set 12 | ryde
# Processing Record 2 of Set 12 | playas
# Processing Record 3 of Set 12 | ahipara
# Processing Record 4 of Set 12 | cam ranh
# Processing Record 5 of Set 12 | cairns
# Processing Record 6 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 12 | labuhan
# Processing Record 8 of Set 12 | kashi
# Processing Record 9 of Set 12 | kigorobya
# Processing Record 10 of Set 12 | west mifflin
# Processing Record 11 of Set 12 | humaita
# Processing Record 12 of Set 12 | santa maria
# Processing Record 13 of Set 12 | boyolangu
# Processing Record 14 of Set 12 | half moon bay
# Processing Record 15 of Set 12 | ngunguru
# Processing Record 16 of Set 12 | maniitsoq
# Processing Record 17 of Set 12 | saravena
# Processing Record 18 of Set 12 | taltal
# Processing Record 19 of Set 12 | pascagoula
# Processing Record 20 of Set 12 | sinnamary
# Processing Record 21 of Set 12 | novobessergenevka
# Processing Record 22 of Set 12 | katobu
# Processing Record 23 of Set 12 | perry
# Processing Record 24 of Set 12 | kysyl-syr
# Processing Record 25 of Set 12 | salinopolis
# Processing Record 26 of Set 12 | sala
# Processing Record 27 of Set 12 | roswell
# Processing Record 28 of Set 12 | kerema
# Processing Record 29 of Set 12 | avon park
# Processing Record 30 of Set 12 | ust-barguzin
# Processing Record 31 of Set 12 | agadir
# Processing Record 32 of Set 12 | saint george
# Processing Record 33 of Set 12 | puerto penasco
# Processing Record 34 of Set 12 | porto walter
# Processing Record 35 of Set 12 | mujiayingzi
# Processing Record 36 of Set 12 | batagay
# Processing Record 37 of Set 12 | sakakah
# Processing Record 38 of Set 12 | griffith
# Processing Record 39 of Set 12 | okhotsk
# Processing Record 40 of Set 12 | shihezi
# Processing Record 41 of Set 12 | ust-omchug
# Processing Record 42 of Set 12 | ulaangom
# Processing Record 43 of Set 12 | lamar
# Processing Record 44 of Set 12 | andenes
# Processing Record 45 of Set 12 | camacupa
# Processing Record 46 of Set 12 | urfa
# City not found. Skipping...
# Processing Record 47 of Set 12 | nantucket
# Processing Record 48 of Set 12 | sinjai
# Processing Record 49 of Set 12 | mangualde
# Processing Record 50 of Set 12 | zhongshu
# Processing Record 1 of Set 13 | vadlapudi
# Processing Record 2 of Set 13 | ixtapa
# Processing Record 3 of Set 13 | cockburn town
# Processing Record 4 of Set 13 | tarakan
# Processing Record 5 of Set 13 | guadalupe y calvo
# Processing Record 6 of Set 13 | florianopolis
# Processing Record 7 of Set 13 | nacala
# Processing Record 8 of Set 13 | mandalgovi
# Processing Record 9 of Set 13 | lerwick
# Processing Record 10 of Set 13 | jos
# Processing Record 11 of Set 13 | buraydah
# Processing Record 12 of Set 13 | songea
# Processing Record 13 of Set 13 | valparaiso
# Processing Record 14 of Set 13 | honiara
# Processing Record 15 of Set 13 | muswellbrook
# Processing Record 16 of Set 13 | peddapuram
# Processing Record 17 of Set 13 | kampene
# Processing Record 18 of Set 13 | mount gambier
# Processing Record 19 of Set 13 | kempsey
# Processing Record 20 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 21 of Set 13 | seymchan
# Processing Record 22 of Set 13 | muslyumovo
# Processing Record 23 of Set 13 | smidovich
# Processing Record 24 of Set 13 | bolshiye uki
# City not found. Skipping...
# Processing Record 25 of Set 13 | pernik
# Processing Record 26 of Set 13 | purpe
# Processing Record 27 of Set 13 | higuey
# City not found. Skipping...
# Processing Record 28 of Set 13 | adrar
# Processing Record 29 of Set 13 | praia da vitoria
# Processing Record 30 of Set 13 | dukat
# Processing Record 31 of Set 13 | muisne
# Processing Record 32 of Set 13 | santa lucia
# Processing Record 33 of Set 13 | jinchang
# Processing Record 34 of Set 13 | gazni
# City not found. Skipping...
# Processing Record 35 of Set 13 | colares
# Processing Record 36 of Set 13 | havre
# Processing Record 37 of Set 13 | ondangwa
# Processing Record 38 of Set 13 | sur
# Processing Record 39 of Set 13 | mae sai
# Processing Record 40 of Set 13 | parrita
# Processing Record 41 of Set 13 | phan thiet
# Processing Record 42 of Set 13 | puerto madero
# Processing Record 43 of Set 13 | manicore
# Processing Record 44 of Set 13 | stephenville
# Processing Record 45 of Set 13 | aykhal
# Processing Record 46 of Set 13 | khilok
# Processing Record 47 of Set 13 | lhokseumawe
# Processing Record 48 of Set 13 | luang prabang
# Processing Record 49 of Set 13 | jardim
# Processing Record 50 of Set 13 | gigmoto
# Processing Record 1 of Set 14 | at-bashi
# Processing Record 2 of Set 14 | aranos
# Processing Record 3 of Set 14 | lashio
# Processing Record 4 of Set 14 | khandyga
# Processing Record 5 of Set 14 | sao mateus do sul
# Processing Record 6 of Set 14 | osa
# Processing Record 7 of Set 14 | sao joao da barra
# Processing Record 8 of Set 14 | veliki preslav
# Processing Record 9 of Set 14 | gat
# Processing Record 10 of Set 14 | kudat
# Processing Record 11 of Set 14 | danville
# Processing Record 12 of Set 14 | cervo
# Processing Record 13 of Set 14 | celbridge
# Processing Record 14 of Set 14 | ovsyanka
# Processing Record 15 of Set 14 | santa cruz
# Processing Record 16 of Set 14 | quatre cocos
# Processing Record 17 of Set 14 | skelleftea
# Processing Record 18 of Set 14 | jumla
# Processing Record 19 of Set 14 | pousat
# City not found. Skipping...
# Processing Record 20 of Set 14 | chernenko
# Processing Record 21 of Set 14 | nago
# Processing Record 22 of Set 14 | ilembula
# Processing Record 23 of Set 14 | kochi
# Processing Record 24 of Set 14 | braunfels
# Processing Record 25 of Set 14 | plast
# Processing Record 26 of Set 14 | boali
# Processing Record 27 of Set 14 | mnogovershinnyy
# Processing Record 28 of Set 14 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 29 of Set 14 | belyy yar
# Processing Record 30 of Set 14 | korsor
# Processing Record 31 of Set 14 | dali
# Processing Record 32 of Set 14 | algiers
# Processing Record 33 of Set 14 | verkhnyachka
# Processing Record 34 of Set 14 | victoria point
# Processing Record 35 of Set 14 | bon accord
# Processing Record 36 of Set 14 | meulaboh
# Processing Record 37 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 14 | caravelas
# Processing Record 39 of Set 14 | arawa
# Processing Record 40 of Set 14 | la rioja
# Processing Record 41 of Set 14 | nacozari
# Processing Record 42 of Set 14 | san patricio
# Processing Record 43 of Set 14 | tumarbong
# Processing Record 44 of Set 14 | bijie
# Processing Record 45 of Set 14 | manokwari
# Processing Record 46 of Set 14 | grand forks
# Processing Record 47 of Set 14 | dryden
# Processing Record 48 of Set 14 | sohag
# Processing Record 49 of Set 14 | salta
# Processing Record 50 of Set 14 | mariel
# Processing Record 1 of Set 15 | ostersund
# Processing Record 2 of Set 15 | bela vista
# Processing Record 3 of Set 15 | winnemucca
# Processing Record 4 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 15 | mackenzie
# Processing Record 6 of Set 15 | ternate
# Processing Record 7 of Set 15 | druzhba
# Processing Record 8 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 9 of Set 15 | svetlyy
# Processing Record 10 of Set 15 | kununurra
# Processing Record 11 of Set 15 | roma
# Processing Record 12 of Set 15 | san alberto
# Processing Record 13 of Set 15 | kedrovyy
# Processing Record 14 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 15 | marzuq
# Processing Record 16 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 15 | ziro
# Processing Record 18 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 19 of Set 15 | baker city
# Processing Record 20 of Set 15 | doba
# Processing Record 21 of Set 15 | huarmey
# Processing Record 22 of Set 15 | karamken
# City not found. Skipping...
# Processing Record 23 of Set 15 | bartica
# Processing Record 24 of Set 15 | abomey
# Processing Record 25 of Set 15 | dabat
# Processing Record 26 of Set 15 | dutlwe
# Processing Record 27 of Set 15 | abu samrah
# Processing Record 28 of Set 15 | huntsville
# Processing Record 29 of Set 15 | bardiyah
# Processing Record 30 of Set 15 | san pedro
# Processing Record 31 of Set 15 | katherine
# Processing Record 32 of Set 15 | hokitika
# Processing Record 33 of Set 15 | bay roberts
# Processing Record 34 of Set 15 | mildura
# Processing Record 35 of Set 15 | sola
# Processing Record 36 of Set 15 | hearst
# Processing Record 37 of Set 15 | saint paul
# Processing Record 38 of Set 15 | ravar
# Processing Record 39 of Set 15 | tabou
# Processing Record 40 of Set 15 | guiratinga
# Processing Record 41 of Set 15 | ocos
# Processing Record 42 of Set 15 | pierre
# Processing Record 43 of Set 15 | bucsa
# Processing Record 44 of Set 15 | nouakchott
# Processing Record 45 of Set 15 | okoneshnikovo
# Processing Record 46 of Set 15 | agirish
# Processing Record 47 of Set 15 | neiafu
# Processing Record 48 of Set 15 | maloshuyka
# City not found. Skipping...
# Processing Record 49 of Set 15 | nizwa
# Processing Record 50 of Set 15 | nouadhibou
# Processing Record 1 of Set 16 | wanning
# Processing Record 2 of Set 16 | mikropolis
# Processing Record 3 of Set 16 | kemijarvi
# Processing Record 4 of Set 16 | cayambe
# Processing Record 5 of Set 16 | sahrak
# City not found. Skipping...
# Processing Record 6 of Set 16 | viedma
# Processing Record 7 of Set 16 | linping
# Processing Record 8 of Set 16 | rosignol
# Processing Record 9 of Set 16 | yazykovo
# Processing Record 10 of Set 16 | cozumel
# Processing Record 11 of Set 16 | kirksville
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': -92.5833, 'lat': 40.1948},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 60.4,
#   'feels_like': 53.02,
#   'temp_min': 60.01,
#   'temp_max': 60.8,
#   'pressure': 1024,
#   'humidity': 41},
#  'visibility': 10000,
#  'wind': {'speed': 8.05, 'deg': 180},
#  'clouds': {'all': 1},
#  'dt': 1615248614,
#  'sys': {'type': 1,
#   'id': 4545,
#   'country': 'US',
#   'sunrise': 1615206765,
#   'sunset': 1615248574},
#  'timezone': -21600,
#  'id': 5055787,
#  'name': 'Kirksville',
#  'cod': 200}

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

#Reorder columns: City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, & Description
new_column_order = ["City", "Country", "Lat", "Lng", 
                    "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

#Assign new column order to DF
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Nikolskoye      RU  59.7035   30.7861     10.99        78          40
# 1      Nongan      CN  44.3820  125.1685     35.60        51           0
# 2   Esperance      AU -33.8667  121.9000     66.20        88          75
# 3   Jamestown      US  42.0970  -79.2353     45.00        49          40
# 4    Hermanus      ZA -34.4187   19.2345     59.00        70          75
# 5      Atuona      PF  -9.8000 -139.0333     79.29        74          65
# 6        Okha      RU  53.5739  142.9478     13.87        94          72
# 7      Eureka      US  40.8021 -124.1637     48.99        77          94
# 8        Asau      RO  46.4333   26.4000     28.99        65          93
# 9       Akyab      MM  20.1500   92.9000     69.10        90           3
#
#    Wind Speed Current Description
# 0        4.47          light snow
# 1       13.42           clear sky
# 2        9.22       broken clouds
# 3       12.03    scattered clouds
# 4        3.00       broken clouds
# 5       14.38       broken clouds
# 6        5.50       broken clouds
# 7        1.01     overcast clouds
# 8        2.51          light snow
# 9        5.91           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
#Confirm no blanks
city_data_df.count()
# Out:
# City                   703
# Country                703
# Lat                    703
# Lng                    703
# Max Temp               703
# Humidity               703
# Cloudiness             703
# Wind Speed             703
# Current Description    703
# dtype: int64
